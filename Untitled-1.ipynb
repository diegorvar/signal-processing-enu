# %% [markdown]
# ## Oscilation Analysis

# %%
import numpy as np
import pandas as pd

# %%
station_metadata = pd.read_csv('/Users/dlugardo/Documents/GitHub/signal-processing-enu/LTM/LTM_station_metadata.csv')
# Out:
#    station  start_date    end_date  years_of_data
# 0     JWLF  2014-08-18  2025-03-02          10.54
# 1     JGBL  2014-08-17  2025-03-02          10.54
# 2     THU2  2003-01-01  2014-12-04          11.92
# 3     NNVN  2014-09-02  2025-03-02          10.50
# 4     YMER  2009-08-18  2025-03-02          15.54
# 5     KMOR  2007-09-03  2025-03-02          17.49
# 6     BLAS  2014-08-21  2025-03-02          10.53
# 7     KLSQ  2014-06-15  2025-03-03          10.72
# 8     MARG  2007-08-30  2025-03-02          17.51
# 9     HRDG  2014-08-17  2025-03-02          10.54
# 10    KELY  2010-03-20  2018-05-30           8.19
# 11    ILUL  2011-06-27  2024-11-23          13.41
# 12    KBUG  2014-08-31  2025-03-02          10.50
# 13    DGJG  2009-08-11  2025-03-02          15.56
# 14    WTHG  2009-08-13  2025-03-02          15.55
# 15    AASI  2009-01-07  2023-08-20          14.61
# 16    HJOR  2014-08-31  2025-03-02          10.50
# 17    DMHN  2011-11-17  2018-12-15           7.08
# ...

# %%
stations_long = []

# %%
stations_long = station_metadata.loc[
    station_metadata['years_of_data'] >= 10, 'station'].unique().tolist()

# %%
for station in stations_long:
